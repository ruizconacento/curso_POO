# %% [markdown]
# <a href="https://colab.research.google.com/github/ruizconacento/curso_POO/blob/main/platzi_curso_basico_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Conversor de monedas

# %%
menu = """ 
👀 Bienvenido al conversor de monedas:
1 - Pesos colombianos
2 - Pesos Argentinos
3 - Pesos Mexicanos
"""
moneda = input(menu)
if moneda == "1":
    print("Elegiste pesos colombianos")
    moneda_local = input("¿Cuántos pesos tienes?: ")
    moneda_local = float(moneda_local)
    valor_dolares = 3819.84
    dolares = moneda_local / valor_dolares
    dolares = round(dolares,2)
    dolares = str(dolares)
    print("Tienes "+dolares+" dolares")
elif moneda == "2":
    print("Elegiste pesos argentinos") 
    moneda_local = input("¿Cuántos pesos tienes?: ")
    moneda_local = float(moneda_local)
    valor_dolares = 109.54
    dolares = moneda_local / valor_dolares
    dolares = round(dolares,2)
    dolares = str(dolares)
    print("Tienes "+dolares+" dolares")

elif moneda == "3":
    print("Elegiste pesos Mexicanos")
    moneda_local = input("¿Cuántos pesos tienes?: ")
    moneda_local = float(moneda_local)
    valor_dolares = 20.36
    dolares = moneda_local / valor_dolares
    dolares = round(dolares,2)
    dolares = str(dolares)
    print("Tienes "+dolares+" dolares")
else: 
  print("No elegiste una moneda válida en el menú")

# %% [markdown]
# Condicionales

# %%
edad = int(input("¿Qué edad tienes?: "))
if edad < 17:
  print("Eres menor de edad, pa tu casa")
else:
  print("Eres mayor")
# Out:
# ¿Qué edad tienes?: 24
# Eres mayor

# %% [markdown]
# Funciones

# %%
def imprimir_mensaje():
    print("Hola")
  
imprimir_mensaje()

# %%
def suma(a,b):
  print()

# %%
def conversacion(mensaje):
  print("Hola, ¿cómo estás? \n"+mensaje+"\nAdiós")

opcion = int(input("Elige una opción(1, 2, 3): "))
if opcion == 1:
    conversacion("Elegiste la opción 1")
elif opcion == 2:
    conversacion("Elegiste la opción 2")
elif opcion == 3: 
    conversacion("Elegiste la opción 3")
else:
  print("Elegiste una opción incorrecta")

# %% [markdown]
# Conversor con funciones

# %%
def conversor(tipo_pesos, valor_dolares):
    moneda_local = input("¿Cuántos pesos "+ tipo_pesos + " tienes?")
    moneda_local = float(moneda_local)
    dolares = moneda_local / valor_dolares
    dolares = round(dolares,2)
    dolares = str(dolares)
    print("Tienes "+dolares+" dolares")
menu = """ 
👀 Bienvenido al conversor de monedas:
1 - Pesos colombianos
2 - Pesos Argentinos
3 - Pesos Mexicanos
"""
moneda = input(menu)
if moneda == "1":
     conversor("Pesos colombianos",3819.84)
elif moneda == "2":
    conversor("Pesos Argentinos",109.54)
elif moneda == "3":
    conversor("Pesos Mexicanos",20.36)
else: 
  print("No elegiste una moneda válida en el menú")

# %% [markdown]
# Cadenas de caracteres

# %%
name = input("Ingresa tu nombre")
name = name.capitalize()
print(name)
name = name.upper()
print(name)
name = name.lower()
print(name)
name = name.strip()
print(name)
name = name[::-1]
print(name)
name = name.replace("m","n")
print(name)

# %%
name = input("ingresa tu nombre: ")
name = name[1:5:1]
print(name)

# %% [markdown]
# Proyecto palíndromo

# %%
def palindromo(palabra):
    palabra = palabra.lower()
    palabra = palabra.replace(" ","")
    palabra_invertida = palabra[::-1]
    if palabra == palabra_invertida:
        return True
    else:
        return False



def run():
    palabra = input("Escribe una palabra: ")
    es_palindromo = palindromo(palabra)
    if es_palindromo == True:
        print("¡La palabra que escribiste es un palíndromo!")
    else:
        print("La palabra que escribiste no es un palíndromo ")


if __name__ == '__main__':
    run()

# %% [markdown]
# Bucles:

# %%
def run():
  LIMITE = 1000
  print("Mi límite es: "+str(LIMITE))
  contador = 0
  potencia = 2**contador
  while potencia < LIMITE:
    print("La potencia de 2 a la " +str(contador) +" es: "+str(potencia))
    contador +=1
    potencia =2**contador
    #print("La potencia de 2 a la " +str(contador) +" es: "+str(potencia))

if __name__ == '__main__':
    run()

# %%
for i in range(1000):
    print(i)

# %%
def run():
    """nombre = input("Escribe tu nombre: ")
    for letra in nombre:
      print(letra)"""

    frase = input("Escribe una frase cualquiera 🤔: ")
    for caracter in frase:
      print(caracter.upper())

if __name__ =='__main__':
  run()

# %% [markdown]
# break and continue

# %%
for i in range(10):
  if i==5:
    continue
  print(i)

# %%
for i in range(10):
  if i==4:
    break
  print(i)

# %%
def run(): 
    texto = input("Escribe una frase o palabra")
    print("tu frase es: "+ texto)
    texto = texto.lower()
    for i in texto:
        if i == "e":
          break
        print(i)
if __name__ == '__main__':
  run()
# Out:
# Escribe una frase o palabraPrueba
# tu frase es: Prueba
# p
# r
# u

# %%
def run():
    for i in range(10):
      if i %2 ==0:
        continue
      print(i)


if __name__ == '__main__':
  run()

# %%
i=0
while i < 10:
    i += 1
    if i == 3:
      continue
    print(i)

# %% [markdown]
# Numeros primos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def es_primo(numero):
  contador = 0
  
  for i in range(1, numero + 1):
    if i == 1 or i == numero:
      continue
    if numero % i == 0:
        contador += 1
  if contador == 0:
    return True
  else:
    return False


def run():
    numero = int(input("Escribe un número para saber si es primo: "))
    if es_primo(numero):
      print("Es primo")
    else: 
      print("No es un número primo")  


if __name__ == '__main__':
  run()

# %% [markdown]
# Adivina el número 1 al 100:

# %%
import random


def run():
    vidas = 5
    print("Tienes: "+str(vidas)+" vidas para jugar")
    numero = int(input("Adivina qué número pienso: "))
    numero_aleatorio = random.randint(0,100)
    print("Tu numero es: "+str(numero))
    while numero != numero_aleatorio:
        vidas -= 1
        print("Te quedan "+str(vidas)+" vidas")
        if numero > numero_aleatorio:
          print("Es mayor al número que pienso")
        elif numero < numero_aleatorio:
          print("Es menor al número que pienso")
        numero = int(input("Adivina qué número pienso: "))
        if vidas == 0:
          break
    print("Felicidades, el número que pienso es: "+str(numero))
    
        



if __name__ == '__main__':
  run()

# %% [markdown]
# LISTAS, recordar clase de strings

# %%
objetos=["Hola", 2, 4.5]
print(objetos)

objetos.append(False)
print(objetos)

objetos.pop(1)
for elemento in objetos:
    print(elemento)
print(objetos[::-1])

print(objetos*5)
# Out:
# ['Hola', 2, 4.5]
# ['Hola', 2, 4.5, False]
# Hola
# 4.5
# False
# [False, 4.5, 'Hola']
# ['Hola', 4.5, False, 'Hola', 4.5, False, 'Hola', 4.5, False, 'Hola', 4.5, False, 'Hola', 4.5, False]

# %% [markdown]
# Tuplas

# %%
mi_tupla = (1, 2, 3, 4, 5)
#Las tuplas son inmutables
for numero in mi_tupla:
  print(numero)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# _DICCIONARIOS_

# %%
def run():
    poblacion_paises= {
        'Argentina':1,
        'Mexico': 2,
        'Colombia':3
    }

    for pais in poblacion_paises.keys():
      print(pais)

    for pais in poblacion_paises.values():
      print(pais)

    for pais, poblacion in poblacion_paises.items():
      print(pais + " tiene "+str(poblacion)+ " habitantes")

if __name__ == '__main__':
    run()
# Out:
# Argentina
# Mexico
# Colombia
# 1
# 2
# 3
# Argentina tiene 1 habitantes
# Mexico tiene 2 habitantes
# Colombia tiene 3 habitantes

# %% [markdown]
# **GENERADOR DE CONTRASEÑAS**

# %%
import random


def generar_contrasena():
    MAYUS = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M', 'N', 'Ñ', 'O', 'P', 'Q', 'R', 'S', 'T', 'U', 'V', 'X', 'Y', 'Z']
    MINUS = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm', 'n', 'ñ', 'o', 'p', 'q', 'r', 's', 't', 'u', 'v', 'x', 'y', 'z']
    NUMS = ['1', '2', '3', '4', '5', '6', '7', '8', '9', '0']
    CHARS = ['*', '+', '-', '/', '@', '_', '?', '!', '[', '{', '(', ')', '}', ']', ',', ';', '.', '>', '<', '~', '°', '^', '&', '$', '#', '"']  

    caracteres = MAYUS + MINUS + NUMS + CHARS
    contrasena = []

    for i in range(15):
      caracter_random = random.choice(caracteres)
      contrasena.append(caracter_random)

    contrasena = "".join(contrasena)
    return contrasena


def run():
  contrasena = generar_contrasena()
  print("Tu nueva contraseña es: "+ contrasena)

if __name__=='__main__':
  run()
